# %% [markdown]
# **This notebook is an exercise in the [Pandas](https://www.kaggle.com/learn/pandas) course.  You can reference the tutorial at [this link](https://www.kaggle.com/residentmario/creating-reading-and-writing).**
#
# ---

# %% [markdown]
# # Introduction
#
# The first step in most data analytics projects is reading the data file. In this exercise, you'll create Series and DataFrame objects, both by hand and by reading data files.
#
# Run the code cell below to load libraries you will need (including code to check your answers).

# %%
import pandas as pd

pd.set_option('display.max_rows', 5)
from learntools.core import binder; binder.bind(globals())
from learntools.pandas.creating_reading_and_writing import *
print("Setup complete.")
# Out:
# Setup complete.

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1.
#
# In the cell below, create a DataFrame `fruits` that looks like this:
#
# ![](https://storage.googleapis.com/kaggle-media/learn/images/Ax3pp2A.png)

# %%
# Your code goes here. Create a dataframe matching the above diagram and assign it to the variable fruits.
import pandas as pd 

fruits = pd.DataFrame({'Apples': [30], 'Bananas': [21]})
print(fruits)

# Check your answer
# Out:
#    Apples  Bananas
# 0      30       21

# %% [markdown]
# ## 2.
#
# Create a dataframe `fruit_sales` that matches the diagram below:
#
# ![](https://storage.googleapis.com/kaggle-media/learn/images/CHPn7ZF.png)

# %%
# Your code goes here. Create a dataframe matching the above diagram and assign it to the variable fruit_sales.
import pandas as pd

fruit_sales = pd.DataFrame({'Apples': [35,41], 'Bananas': [22,34]})
fruit_sales.index = ['2017 Sales', '2018 Sales']
print(fruit_sales)
# Out:
#             Apples  Bananas
# 2017 Sales      35       22
# 2018 Sales      41       34

# %%
#q2.hint()
#q2.solution()

# %% [markdown]
# ## 3.
#
# Create a variable `ingredients` with a Series that looks like:
#
# ```
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object
# ```

# %%
import pandas as pd

ingredients = pd.DataFrame({'Flour': ['4 cups'],
                           'Milk' : ['1 cup'],
                           'Eggs': ['2 large'],
                           'Spam': ['1 can'],
                           'Name': ['Dinner,dtype: object']})
print(ingredients)
# Out:
#     Flour   Milk     Eggs   Spam                  Name
# 0  4 cups  1 cup  2 large  1 can  Dinner,dtype: object

# %%
#q3.hint()
#q3.solution()

# %% [markdown]
# ## 4.
#
# Read the following csv dataset of wine reviews into a DataFrame called `reviews`:
#
# ![](https://storage.googleapis.com/kaggle-media/learn/images/74RCZtU.png)
#
# The filepath to the csv file is `../input/wine-reviews/winemag-data_first150k.csv`. The first few lines look like:
#
# ```
# ,country,description,designation,points,price,province,region_1,region_2,variety,winery
# 0,US,"This tremendous 100% varietal wine[...]",Martha's Vineyard,96,235.0,California,Napa Valley,Napa,Cabernet Sauvignon,Heitz
# 1,Spain,"Ripe aromas of fig, blackberry and[...]",Carodorum Selección Especial Reserva,96,110.0,Northern Spain,Toro,,Tinta de Toro,Bodega Carmen Rodríguez
# ```

# %%
import pandas as pd

file_path = '../input/wine-reviews/winemag-data_first150k.csv'
wine_data = pd.read_csv(file_path, index_col=2)
print(wine_data)
# Out:
#                                                     Unnamed: 0 country  \
# description
# This tremendous 100% varietal wine hails from O...           0      US
# Ripe aromas of fig, blackberry and cassis are s...           1   Spain
# ...                                                        ...     ...
# A perfect salmon shade, with scents of peaches,...      150928  France
# More Pinot Grigios should taste like this. A ri...      150929   Italy
#
#                                                                              designation  \
# description
# This tremendous 100% varietal wine hails from O...                     Martha's Vineyard
# Ripe aromas of fig, blackberry and cassis are s...  Carodorum Selección Especial Reserva
# ...                                                                                  ...
# A perfect salmon shade, with scents of peaches,...                       Grand Brut Rosé
# More Pinot Grigios should taste like this. A ri...                                   NaN
#
#                                                     points  price  \
# description
# This tremendous 100% varietal wine hails from O...      96  235.0
# Ripe aromas of fig, blackberry and cassis are s...      96  110.0
# ...                                                    ...    ...
# A perfect salmon shade, with scents of peaches,...      90   52.0
# More Pinot Grigios should taste like this. A ri...      90   15.0
#
#                                                               province  \
# description
# This tremendous 100% varietal wine hails from O...          California
# Ripe aromas of fig, blackberry and cassis are s...      Northern Spain
# ...                                                                ...
# A perfect salmon shade, with scents of peaches,...           Champagne
# More Pinot Grigios should taste like this. A ri...  Northeastern Italy
#
#                                                        region_1 region_2  \
# description
# This tremendous 100% varietal wine hails from O...  Napa Valley     Napa
# Ripe aromas of fig, blackberry and cassis are s...         Toro      NaN
# ...                                                         ...      ...
# A perfect salmon shade, with scents of peaches,...    Champagne      NaN
# More Pinot Grigios should taste like this. A ri...   Alto Adige      NaN
#
#                                                                variety  \
# description
# This tremendous 100% varietal wine hails from O...  Cabernet Sauvignon
# Ripe aromas of fig, blackberry and cassis are s...       Tinta de Toro
# ...                                                                ...
# A perfect salmon shade, with scents of peaches,...     Champagne Blend
# More Pinot Grigios should taste like this. A ri...        Pinot Grigio
#
#                                                                      winery
# description
# This tremendous 100% varietal wine hails from O...                    Heitz
# Ripe aromas of fig, blackberry and cassis are s...  Bodega Carmen Rodríguez
# ...                                                                     ...
# A perfect salmon shade, with scents of peaches,...                   Gosset
# More Pinot Grigios should taste like this. A ri...            Alois Lageder
#
# [150930 rows x 10 columns]

# %%
#q4.hint()
#q4.solution()

# %% [markdown]
# ## 5.
#
# Run the cell below to create and display a DataFrame called `animals`:

# %%
import pandas as pd

animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
print(animals)
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19

# %% [markdown]
# In the cell below, write code to save this DataFrame to disk as a csv file with the name `cows_and_goats.csv`.

# %%
animals.to_csv('cows_and_goats.csv')
print('DataFrame has been saved as cows_and_goats.csv')
# Out:
# DataFrame has been saved as cows_and_goats.csv

# %%
#q5.hint()
#q5.solution()

# %% [markdown]
# # Keep going
#
# Move on to learn about **[indexing, selecting and assigning](https://www.kaggle.com/residentmario/indexing-selecting-assigning)**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/pandas/discussion) to chat with other learners.*
